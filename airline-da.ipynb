# %%
# Load packages

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# List files under cwd

#import os
#for dirname, _, filenames in os.walk(os.getcwd()):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# %%
# Import CSV files

industry_totals = pd.read_csv('industry_totals.csv')

# %%
industry_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 79 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Year                                                     24 non-null     int64
#  1   Total Operating Revenue ($)                              24 non-null     float64
#  2   System Passenger Revenue ($)                             24 non-null     float64
#  3   System Total Transport Related Revenue ($)               24 non-null     float64
#  4   System Passenger Revenue per ASM ($)                     24 non-null     float64
#  5   System Revenue Per ASM (exc-transport) ($ per ASM)       24 non-null     float64
#  6   System Passenger Yield ($ per RPM)                       24 non-null     float64
#  7   Ancillary Fees ($)                                       24 non-null     float64
# ...

# %%
industry_totals.sample(3)
# Out:
#     Year  Total Operating Revenue ($)  System Passenger Revenue ($)  \
# 9   2004                 1.346218e+11                  8.569675e+10
# 21  2016                 2.004136e+11                  1.246334e+11
# 11  2006                 1.646231e+11                  1.012942e+11
#
#     System Total Transport Related Revenue ($)  \
# 9                                 2.291443e+10
# 21                                4.007680e+10
# 11                                3.213266e+10
#
#     System Passenger Revenue per ASM ($)  \
# 9                           8.459621e+09
# 21                          1.134834e+10
# 11                          9.938206e+09
#
#     System Revenue Per ASM (exc-transport) ($ per ASM)  \
# 9                                            0.092436
# 21                                           0.128505
# 11                                           0.106901
#
#     System Passenger Yield ($ per RPM)  Ancillary Fees ($)  International ASM  \
# ...

# %%
# Import CSV files

airline_expenses = pd.read_csv('airline_expenses.csv')

# %%
airline_expenses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               24 non-null     int64
#  1   American           24 non-null     float64
#  2   Continental        24 non-null     float64
#  3   Delta              24 non-null     float64
#  4   Northwest          24 non-null     float64
#  5   United             24 non-null     float64
#  6   US Airways         24 non-null     float64
#  7   America West       24 non-null     float64
#  8    --sub Network     24 non-null     float64
#  9   Southwest          24 non-null     float64
#  10  jetBlue            24 non-null     float64
#  11  AirTran            24 non-null     float64
#  12  Frontier           24 non-null     float64
#  13  Virgin America     24 non-null     float64
#  14   -- sub LCC        24 non-null     float64
# ...

# %%
airline_expenses.sample(3)
# Out:
#     Year      American   Continental         Delta     Northwest  \
# 11  2006  2.100789e+10  1.259997e+10  1.730830e+10  1.177326e+10
# 10  2005  2.100789e+10  1.120173e+10  1.730888e+10  1.321076e+10
# 22  2017  3.816323e+10  0.000000e+00  3.532613e+10  0.000000e+00
#
#           United    US Airways  America West   --sub Network     Southwest  \
# 11  1.888334e+10  1.128830e+10  0.000000e+00    9.286106e+10  8.152040e+09
# 10  1.754550e+10  7.425433e+09  3.517704e+09    9.121789e+10  6.763757e+09
# 22  3.423670e+10  0.000000e+00  0.000000e+00    1.077261e+11  1.765580e+10
#
#     ...      Frontier  Virgin America    -- sub LCC        Alaska  \
# 11  ...  1.144178e+09    0.000000e+00  1.339366e+10  2.796132e+09
# 10  ...  9.623500e+08    0.000000e+00  1.080462e+10  2.423907e+09
# 22  ...  1.673085e+09    1.551659e+09  2.690251e+10  4.997077e+09
#
#         Hawaiian        Spirit     Allegiant   -- sub Other  \
# 11  8.693385e+08  6.071989e+08  2.170720e+08   4.489741e+09
# ...

# %%
airline_passengers = pd.read_csv('airline_passengers.csv')

# %%
airline_passengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               24 non-null     int64
#  1   American           24 non-null     float64
#  2   Continental        24 non-null     float64
#  3   Delta              24 non-null     float64
#  4   Northwest          24 non-null     float64
#  5   United             24 non-null     float64
#  6   US Airways         24 non-null     float64
#  7   America West       24 non-null     float64
#  8    --sub Network     24 non-null     float64
#  9   Southwest          24 non-null     float64
#  10  jetBlue            24 non-null     float64
#  11  AirTran            24 non-null     float64
#  12  Frontier           24 non-null     float64
#  13  Virgin America     24 non-null     float64
#  14   --sub LCC         24 non-null     float64
# ...

# %%
airline_passengers.sample(3)
# Out:
#     Year     American  Continental        Delta   Northwest      United  \
# 0   1995   79567182.0   35284189.0   86963085.0  49370005.0  78807932.0
# 20  2015  146814345.0          0.0  138854392.0         0.0  95555189.0
# 12  2007   98200398.0   49005712.0   73051485.0  53736983.0  68385937.0
#
#     US Airways  America West   --sub Network    Southwest  ...     AirTran  \
# 0   57035260.0    16848329.0     403875982.0   50151362.0  ...    497599.0
# 20         0.0           0.0     381223926.0  144678301.0  ...         0.0
# 12  57865666.0           0.0     400246181.0  101989972.0  ...  23761073.0
#
#       Frontier  Virgin America    --sub LCC      Alaska    Hawaiian  \
# 0     611451.0             0.0   51260412.0  10139128.0   4926466.0
# 20  13104187.0       6993269.0  199906547.0  22868774.0  10459770.0
# 12  10400172.0        383625.0  157839564.0  17559002.0   7098771.0
#
#         Spirit  Allegiant   -- sub Other  Total All Sectors
# ...

# %%
airline_revenues = pd.read_csv('airline_revenues.csv')

# %%
airline_revenues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               24 non-null     int64
#  1   American           24 non-null     float64
#  2   Continental        24 non-null     float64
#  3   Delta              24 non-null     float64
#  4   Northwest          24 non-null     float64
#  5   United             24 non-null     float64
#  6   US Airways         24 non-null     float64
#  7   America West       24 non-null     float64
#  8    --sub Network     24 non-null     float64
#  9   Southwest          24 non-null     float64
#  10  jetBlue            24 non-null     float64
#  11  AirTran            24 non-null     float64
#  12  Frontier           24 non-null     float64
#  13  Virgin America     24 non-null     float64
#  14   -- sub LCC        24 non-null     float64
# ...

# %%
airline_revenues.sample(3)
# Out:
#     Year      American   Continental         Delta     Northwest  \
# 15  2010  2.215094e+10  1.401150e+10  3.189370e+10  0.000000e+00
# 6   2001  1.563879e+10  7.971663e+09  1.321119e+10  9.591793e+09
# 0   1995  1.561020e+10  4.919025e+09  1.255728e+10  8.908851e+09
#
#           United    US Airways  America West   --sub Network     Southwest  \
# 15  1.968232e+10  1.219581e+10  0.000000e+00    9.993426e+10  1.210371e+10
# 6   1.608737e+10  8.253356e+09  2.035474e+09    7.278964e+10  5.555235e+09
# 0   1.489476e+10  6.984876e+09  1.561849e+09    6.543684e+10  2.873482e+09
#
#     ...      Frontier  Virgin America    -- sub LCC        Alaska  \
# 15  ...  1.316949e+09     724877360.0  2.054552e+10  3.426625e+09
# 6   ...  4.466522e+08             0.0  6.987464e+09  1.763063e+09
# 0   ...  5.585034e+07             0.0  2.929332e+09  1.162878e+09
#
#         Hawaiian       Spirit    Allegiant   -- sub Other  Total All Sectors  \
# ...

# %% [markdown]
# #### Oberservation:
#
# Three airline dataframes should be merged
